# %% [markdown]
# <a href="https://colab.research.google.com/github/SamanvithaBolem/SamanvithaBolem/blob/main/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Samanvitha***

# %% [markdown]
# 1. Importing dataset

# %%
import pandas as pd

data = pd.read_csv('/content/first_assessment.csv')

# %%
data.sample()
# Out:
#        country  year   sex  ...   gdp_for_year   gdp_per_capita  generation
# 20762  Romania  2002  male  ...  46,174,557,556            2231  Millenials
#
# [1 rows x 12 columns]

# %% [markdown]
# 2. Examining dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            27820 non-null  object
#  1   year               27820 non-null  int64
#  2   sex                27820 non-null  object
#  3   age                27820 non-null  object
#  4   suicides_no        27820 non-null  int64
#  5   population         27820 non-null  int64
#  6   suicides/100k pop  27820 non-null  float64
#  7   country-year       27820 non-null  object
#  8   HDI for year       8364 non-null   float64
#  9   gdp_for_year       27820 non-null  object
#  10  gdp_per_capita     27820 non-null  int64
#  11  generation         27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %% [markdown]
# 3. **5 categorical data:** country, sex, age, country-year, generation.
#    **5 continuous data:**  population, suicides_no, gdp_per_capita,    suicides/100k pop, HDI for year.
#    **2 discrete data:** year, gdp_for_year.

# %% [markdown]
# 4. Mean, Median, Mode, Std deviation, Variance of data

# %%
print("Mean of data", data.mean())
print("\n \nMedian of data", data.median())
print("\n \nMode of data", data.mode())
print("\n \nStandard deviation of data", data.std())
print("\n \nVariance of data", data.var())
# Out:
# Mean of data year                 2.001258e+03
# suicides_no          2.425744e+02
# population           1.844794e+06
# suicides/100k pop    1.281610e+01
# HDI for year         7.766011e-01
# gdp_per_capita       1.686646e+04
# dtype: float64
#
#
# Median of data year                   2002.000
# suicides_no              25.000
# population           430150.000
# suicides/100k pop         5.990
# HDI for year              0.779
# gdp_per_capita         9372.000
# dtype: float64
#
#
# Mode of data           country    year  ... gdp_per_capita    generation
# 0         Austria  2009.0  ...         1299.0  Generation X
# 1         Iceland     NaN  ...         2303.0           NaN
# 2       Mauritius     NaN  ...         4104.0           NaN
# 3     Netherlands     NaN  ...            NaN           NaN
# 4             NaN     NaN  ...            NaN           NaN
# ...           ...     ...  ...            ...           ...
# 2300          NaN     NaN  ...            NaN           NaN
# ...

# %% [markdown]
# 5. Value counts of data

# %%
data.value_counts()
# Out:
# country     year  sex     age          suicides_no  population  suicides/100k pop  country-year    HDI for year  gdp_for_year     gdp_per_capita  generation
# Uzbekistan  2014  male    75+ years    17           224995      7.56               Uzbekistan2014  0.675         63,067,077,179   2309            Silent          1
# Finland     2014  female  75+ years    11           294322      3.74               Finland2014     0.883         272,609,288,690  52832           Silent          1
#                   male    25-34 years  110          356059      30.89              Finland2014     0.883         272,609,288,690  52832           Millenials      1
#                           35-54 years  207          708947      29.20              Finland2014     0.883         272,609,288,690  52832           Generation X    1
#                           5-14 years   1            303796      0.33               Finland2014     0.883         272,609,288,690  52832           Generation Z    1
# ...

# %% [markdown]
# 6. Line plot, Bar graph, dist plot, histogram, box plot, pair plot,

# %%
import matplotlib.pyplot as plt
import matplotlib_inline

# %%
plt.plot(data['year'])

# %%
plt.plot(data['population'])

# %%
plt.plot(data['country'])

# %%
plt.plot(data['suicides_no'])

# %%
plt.plot(data['HDI for year'])

# %%
import seaborn as sns

# %%
sns.barplot(x='age',
            y='population',
            data=data)

# %%
sns.lineplot(x='age',
            y='population',
            data=data)

# %%
sns.boxplot(x='age',
            y='population',
            data=data)

# %%
sns.pairplot(data, hue='age')

# %% [markdown]
# 7. correlation and heat map

# %%
data.corr()
# Out:
#                        year  suicides_no  ...  HDI for year  gdp_per_capita
# year               1.000000    -0.004546  ...      0.366786        0.339134
# suicides_no       -0.004546     1.000000  ...      0.151399        0.061330
# population         0.008850     0.616162  ...      0.102943        0.081510
# suicides/100k pop -0.039037     0.306604  ...      0.074279        0.001785
# HDI for year       0.366786     0.151399  ...      1.000000        0.771228
# gdp_per_capita     0.339134     0.061330  ...      0.771228        1.000000
#
# [6 rows x 6 columns]

# %%
correlation = data.corr()

# %%
plt.imshow(correlation)

# %% [markdown]
# 8. Grouping data

# %%
gb = data.groupby('age')
gb.first()
# Out:
#              country  year  ... gdp_per_capita       generation
# age                         ...
# 15-24 years  Albania  1987  ...            796     Generation X
# 25-34 years  Albania  1987  ...            796          Boomers
# 35-54 years  Albania  1987  ...            796           Silent
# 5-14 years   Albania  1987  ...            796     Generation X
# 55-74 years  Albania  1987  ...            796  G.I. Generation
# 75+ years    Albania  1987  ...            796  G.I. Generation
#
# [6 rows x 11 columns]

# %%
gs = data.groupby('sex')
gs.first()
# Out:
#         country  year          age  ...  gdp_for_year   gdp_per_capita    generation
# sex                                 ...
# female  Albania  1987  15-24 years  ...  2,156,624,900             796  Generation X
# male    Albania  1987  15-24 years  ...  2,156,624,900             796  Generation X
#
# [2 rows x 11 columns]

# %%
gh= data.groupby('generation')
gh.first()
# Out:
#                  country  year  ...   gdp_for_year  gdp_per_capita
# generation                      ...
# Boomers          Albania  1987  ...   2,156,624,900            796
# G.I. Generation  Albania  1987  ...   2,156,624,900            796
# Generation X     Albania  1987  ...   2,156,624,900            796
# Generation Z     Albania  2007  ...  10,701,011,897           3863
# Millenials       Albania  1992  ...     709,452,584            251
# Silent           Albania  1987  ...   2,156,624,900            796
#
# [6 rows x 11 columns]
